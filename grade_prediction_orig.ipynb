# %% [markdown]
# <a href="https://colab.research.google.com/github/atul799/AI-Essentials-Course/blob/main/grade_prediction_orig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables: store the student's name and age
student_name = 'Alex'
student_age = 16

# %%
#Print
# Print variables student_name and student_age
print(f'Initializing Grade Predictor for {student_name} aged {student_age}')
# Out:
# Initializing Grade Predictor for Alex aged 16

# %%
# List and Sets
#Set , the access to elements of set are the same as shown in list
subjects={'Maths','Science','English','AI','Maths','Science'} # set definition
print('Set subjects is :',subjects)

#add a blank line
print('')

#list
numbers=[10,20,30,40] # list definition
print('first element:',numbers[0]) #first element
print('second element:',numbers[1]) #second element
print('third element:',numbers[2]) #third element
print('fourth element:',numbers[3]) #fourth element

#add a blank line
print('')
# access elements from the end
print('last element:',numbers[-1]) #last element
print('second last element:',numbers[-2]) #second last element

#add a blank line
print('')
#change the list elements
numbers[1]=25
print('Numbers list after changing element at position 2:',numbers)

#add a blank line
print('')

# add elements in a list
numbers.append(50) #add element at end of list
print('List after adding at end-append:',numbers)
numbers.insert(1,15) #add element at position 2
print('List inserting at position 2:',numbers)

#add a blank line
print('')
#remove element from list
numbers.remove(25)
print('List after removing value 25:',numbers)
numbers.pop(2)
print('List after removing element at position 3:',numbers)

#add a blank line
print('')
#find length of the list
print('length of the list:',len(numbers))

#add a blank line
print('')
#find if an element exists
print('list is now:',numbers)
print('0 exist in the list?:',30 in numbers)

#add a blank line
print('')
# slicing a list
number_slice=numbers[1:4] # store 2-3 element in variable number_slice
print('Slice of list:',number_slice)

#add a blank line
print('')
# A list of student scores and subject names
scores=[85,92,78,90,88] #A list of student scores
subjects={'Maths','Physics','Maths','AI','English','AI'} #A list of subjects stired as set to avoid duplicates
print('Scores list:',scores)
print('Subjects list:',subjects)
# Out:
# Set subjects is : {'Maths', 'Science', 'English', 'AI'}
#
# first element: 10
# second element: 20
# third element: 30
# fourth element: 40
#
# last element: 40
# second last element: 30
#
# Numbers list after changing element at position 2: [10, 25, 30, 40]
#
# List after adding at end-append: [10, 25, 30, 40, 50]
# List inserting at position 2: [10, 15, 25, 30, 40, 50]
#
# List after removing value 25: [10, 15, 30, 40, 50]
# List after removing element at position 3: [10, 15, 40, 50]
#
# length of the list: 4
#
# list is now: [10, 15, 40, 50]
# 0 exist in the list?: False
#
# Slice of list: [15, 40, 50]
#
# Scores list: [85, 92, 78, 90, 88]
# Subjects list: {'Maths', 'AI', 'English', 'Physics'}

# %%
# Dictionary
report_card={ 'Maths': 85,
             'Physics':92,
              'AI':90
              }
print('Dict report_card',report_card)

#add a blank line
print('')

student={
    'name':'Joy',
    'age':15,
    'grade':9
    }
print('Dict student',report_card)

#add a separator line using string multiplier
print('-----'*12)

#Access value using key
print('Name by key:',student['name']) #print  value of the key 'name'
print('Age by key:',student['age']) #print  value of the key 'age'


#add a blank line
print('')

#Access value using key with get method
print('Name by get:',student.get('name')) #print  value of the key 'name'
print('Grade by get:',student.get('grade')) #print  value of the key 'grade'

#add a blank line
print('')

#Adding New Ky-Value Pairs
student['school'] = 'Gymnasium Neubiberg' # add school key value pair to dict
print('Dict Student now is:',student)

#add a blank line
print('')

#Modifying existing value
student['age']=16 #change value of key age
print('Dict Student now is:',student)

#add a blank line
print('')

#Removing data from dictionary: del and pop()
del student['grade'] #delete grade key-value pair
print('Dict Student after del grade key is:',student)
student.pop('school') #delete key school by pop() method
print('Dict Student after pop school key is:',student)

#add a blank line
print('')

# checking if a key exist
print('Is name key value pair in dict?:','name' in student)
print('Is grade key value pair in dict?:','grade' in student)

#add a blank line
print('')

#looping through dictionary
for key in student:  #loop through keys
    print('looping with keys',key,':',student[key])
#add a blank line
print('')
for value in student.values():  #loop through values
    print('looping with values :',value)
#add a blank line
print('')
for key,value in student.items():  #loop through keys and values
    print('looping with key and value',key,':',value)
# Out:
# Dict report_card {'Maths': 85, 'Physics': 92, 'AI': 90}
#
# Dict student {'Maths': 85, 'Physics': 92, 'AI': 90}
# ------------------------------------------------------------
# Name by key: Joy
# Age by key: 15
#
# Name by get: Joy
# Grade by get: 9
#
# Dict Student now is: {'name': 'Joy', 'age': 15, 'grade': 9, 'school': 'Gymnasium Neubiberg'}
#
# Dict Student now is: {'name': 'Joy', 'age': 16, 'grade': 9, 'school': 'Gymnasium Neubiberg'}
#
# Dict Student after del grade key is: {'name': 'Joy', 'age': 16, 'school': 'Gymnasium Neubiberg'}
# Dict Student after pop school key is: {'name': 'Joy', 'age': 16}
#
# Is name key value pair in dict?: True
# Is grade key value pair in dict?: False
#
# looping with keys name : Joy
# looping with keys age : 16
#
# looping with values : Joy
# looping with values : 16
#
# looping with key and value name : Joy
# looping with key and value age : 16

# %%
#Logical operators and comparisons
a= 10 #variable 1
b=5   #variable 2

print('a is equal to b:',a==b)
print('a is not equal to b:',a!=b)
print('a is greater than b:',a>b)
print('a is less than b:',a<b)
print('a is greater than or equal to b:',a>=b)
print('a is less than or equal to b:',a<=b)


#add a blank line
print('')
#chained comparison
age= 16
print('Age is between 13 and 18?', 13<= age <=18)
height= 155
print('Height is between 130 and 150?', 130<= height <=150)

#add a blank line
print('')

#String comparison
print('is apple and apple same for Python?','apple' == 'apple')
print('is Apple and apple same for Python?','Apple' == 'apple')

#add a blank line
print('')
#Logical Operators
#AND, OR , NOT
a=1
b=0
c=1
d=0
and_1=a and b
and_2=a and c
print(f'AND operator output when one input is 0 is {and_1} and when both inputs are 1 is {and_2}')
#add a blank line
print('')
or_1 = a or b
or_2 = a or c
or_3= b or d
print(f'OR operator output when one input is 1 is {or_1} and when both inputs are 1 is {or_2} and when both inputs are 0 is {or_3}')

#add a blank line
print('')
not_1= not a
not_2= not b
print(f'when input to not operator is {a} output is {not_1} and when input is {b}, output is {not_2}')
# Out:
# a is equal to b: False
# a is not equal to b: True
# a is greater than b: True
# a is less than b: False
# a is greater than or equal to b: True
# a is less than or equal to b: False
#
# Age is between 13 and 18? True
# Height is between 130 and 150? False
#
# is apple and apple same for Python? True
# is Apple and apple same for Python? False
#
# AND operator output when one input is 0 is 0 and when both inputs are 1 is 1
#
# OR operator output when one input is 1 is 1 and when both inputs are 1 is 1 and when both inputs are 0 is 0
#
# when input to not operator is 1 output is False and when input is 0, output is True

# %%
# Control flow
# Conditional Control flow: if-elif-else

#code with linear control flow, i.e. code runs line by line
print('Start')
print('Middle')
print('End')

#add a blank line
print('')

# example of code with conditional control flow, print statement executes only
#if condition age >=10 condition is satisfied, to test change age=15 to age=9

age=15
if age >=10:
  print('You are old enough to play the game')

#add a blank line
print('')
# what to do in either case if the condition is treu and not true
score=45
if score >=60:
  print('You passed the exam') #execute print if condition True
else:
  print('You failed the exam') #execute print if condition not True

#add a blank line
print('')

#Multiple condition test example
marks=85
if marks >=90:
  print('You got an A')
  print('Congratulations!')
elif marks >=80:
  print('You got a B')
  print('Good job!')
elif marks >=70:
  print('You got a C')
  print('Keep it up!')
else:
  print('You got a D')
  print('Keep trying!')

#add a blank line
print('')

passing_score=80
current_score=92
#logic comparision (greater than)
if current_score >= passing_score:
  status = 'Elite'
elif current_score >= 50:
  status='Passing'
else:
  status='Needs Help'

print(f'Your current score is {current_score} and you are {status}')
# Out:
# Start
# Middle
# End
#
# You are old enough to play the game
#
# You failed the exam
#
# You got a B
# Good job!
#
# Your current score is 92 and you are Elite

# %%
# Control flow
# Loops: for and while

#for loop is used when number of repeatitions can be oredicted upfront
print('For Loop')
for i in range(3): #range(3) means a list [0,1,2], so this loop
  print(i)

#add a blank line
print('')
#while loop is used when loop repeatitions depend on condition
count =0 #initialize count as 0
print('While Loop')
while count <3: #loop until count is less than 3,
  print(count)  # print count as long as looping
  count +=1    # increase value of count by 1

#add a blank line
print('')
#break is used to quit looping if a condition during loop becomes true
looplist=[0,1,2,3,4]
print('For Loop with break')
for i in looplist: #initial goal is to loop 5 times with [0,1,2,3,4]
  if i==3:         # if looplist contains 3, then quit looping
    break          # break quits the loop
  print(i)
#add a blank line
print('')
looplist=[0,1,2,4,5]
print('For Loop with break when break condition not met')
for i in looplist: #initial goal is to loop 5 times with [0,1,2,3,4]
  if i==3:         # if looplist contains 3, then quit looping
    break          # break quits the loop
  print(i)
#add a blank line
print('')

#continue is used to skip an iteration in a loop without breaking the loop
looplist=[0,1,2,3,4]
print('For Loop with continue')
for i in looplist: #initial goal is to loop 5 times with [0,1,2,3,4]
  if i==2:         # if looplist contains 3, then skip looping
    continue          # continue skips the current loop
  print(i)
#add a blank line
print('------'*12)

#code for grade predictor program
total=0
#loop throught he list to calculate the sum
for s in scores:
  total = total+s

average=total/len(scores) #formula for average
print(f'The Average score is:{average}')
# Out:
# For Loop
# 0
# 1
# 2
#
# While Loop
# 0
# 1
# 2
#
# For Loop with break
# 0
# 1
# 2
#
# For Loop with break when break condition not met
# 0
# 1
# 2
# 4
# 5
#
# For Loop with continue
# 0
# 1
# 3
# 4
# ------------------------------------------------------------------------
# The Average score is:86.6

# %%
# function
#function without parameters and no return value
def greet():  #defintion of function with name greet
  print('Hello')   #things to do when function is called, in this case only a print statement
greet()       #function called, function has to be defined before calling
#add a blank line
print('')

#function with parameters and no return value
def greet(name):  #defintion of function, name is a parameter that can be passed an argument when calling
  print(f'Hello {name}')   #things to do when function is called, in this case only a print statement
greet('Joy')       #function called with argument Joy, name will be mapped to Joy
greet('Ray')      #function called with argument Ray, name will be mapped to Ray
#add a blank line
print('')

#function with 2 parameters
def add(a,b): #function defintion, name add and parameters a and b
  print(f'Sum of {a} and {b} is {a+b}') # inside function value of a+b is to be printed

add(3,5)    #function called with arguments 3 & 2 which are mapped to a & b
add(100,110)  #function called with arguments 100 & 110 which are mapped to a & b

#add a blank line
print('')

# functions can return values after completing tasks inside the function block
# that can then be further used in the main program
def add(a,b): #function defintion, name add and parameters a and b
  return a+b # function send value of a+b to main program

retval=add(3,5) #in this value of a+b is assigned to variable retval
print('return value from add function is:',retval)

#add a blank line
print('')
#function when defined can have default value so if arguement is not passed they can use default value
def add(a=3,b=2): #function defintion, name add and parameters a and b with default values
  return a+b # function send value of a+b to main program

retval=add() #in this value of a+b is assigned to variable retval
print('return value from add function with default args is:',retval)

#while calling a function, arguments can be assigned by name, in which case use parameter=arg in function call
retval1=add(a=6)
print('return value from add function with assignment by name is:',retval1)

#add a blank line
print('')
#function to predict perforamnce for grading prediction program
def predict_performance(avg):
  if avg > 85:
    return "High Potential"
  else:
    return "Standard"

#calling function
prediction = predict_performance(average)
print('Prediction: ', prediction)
# Out:
# Hello
#
# Hello Joy
# Hello Ray
#
# Sum of 3 and 5 is 8
# Sum of 100 and 110 is 210
#
# return value from add function is: 8
#
# return value from add function with default args is: 5
# return value from add function with assignment by name is: 8
#
# Prediction:  High Potential

# %%
#Input output

#user input from terminal
#the computer waits for the user to type input at terminal
student_name=input('Please enter your name:')
print(f'Welcome, {student_name}')

#add a blank line
print('')

#Writing to file
average=85
report_text1=f'Report for {student_name}'
report_text2=f'Passed with score {average}'
with open('student_report.txt','w') as file: #open file with name student_report to write
  file.write(report_text1+ '\n'+report_text2)   #file is called a filehandle used to refer to file on disk, 2 lines are added
print('Report save to student_report.txt file')

#add a blank line
print('')

#Reading from a file
# read all content at one go
file=open('student_report.txt','r') #this time file handle 'file' is created standalone, so have to close after file read is complete
content=file.read()  #read all of the file content into variable content
print('All file content read at one go')
print(content)
file.close()       #close the file handle

#add a blank line
print('')

# read file line by line
file=open('student_report.txt','r') #this time file handle 'file' is created standalone, so have to close after file read is complete
print('file read line by line')
i=0
for line in file:  #filehandle loops through file content line by line
  i +=1
  print(f'line {i} in file: {line}',end='')
file.close()       #close the file handle
# Out:
# Please enter your name:Jay
# Welcome, Jay
#
# Report save to student_report.txt file
#
# All file content read at one go
# Report for Jay
# Passed with score 85
#
# file read line by line
# line 1 in file: Report for Jay
# line 2 in file: Passed with score 85

# %%
import matplotlib.pyplot as plt

# --- 1. FUNCTIONS ---
def analyze_grades(name, score_list):
    avg = sum(score_list) / len(score_list)
    status = "University Ready" if avg > 80 else "Needs Improvement"

    # Create a nice summary string
    summary = f"GRADE REPORT\n"
    summary += f"Student: {name}\n"
    summary += f"Average Score: {avg}\n"
    summary += f"Final Decision: {status}\n"
    return avg, summary

# --- 2. INPUT ---
print("--- Grade Predictor System ---")
user_name = input("Enter student name, then hit Enter: ")
# We ask for scores separated by spaces, then turn them into integers
raw_scores = input("Enter 5 scores separated by spaces (e.g., 80 90 75 88 92): ")
#user input is treated as text(string), however to do math it has to be converted to integer or real number
#in the code below all elements of raw_score are converted to integer (int(s)) by looping through it and saving result
#in new list score_list, the looping method used here is very special syntax of python called syntactic sugar
score_list = [int(s) for s in raw_scores.split()]

# --- 3. PROCESSING ---
#function returns 2 values which are stored in two variables average and final_report
average, final_report = analyze_grades(user_name, score_list) #calling function to analyze grade

# --- 4. OUTPUT (To Screen) ---
print("\n" + final_report) # the + here is simply adding two strings in this case first string is actually a new line char

# --- 5. WRITING TO FILE (Permanent Storage) ---
file_name = f"{user_name}_report.txt"
with open(file_name, "w") as f:
    f.write(final_report)
print(f"Success! A permanent copy has been saved to {file_name}")

# --- 6. PLOTTING (Visualization) ---
plt.bar(range(1, len(score_list)+1), score_list, color='skyblue')
plt.axhline(y=80, color='r', linestyle='--', label='Threshold')
plt.title(f"Score Distribution for {user_name}")
plt.xlabel("Exam Number")
plt.ylabel("Score")
plt.legend()
plt.show()
# Out:
# --- Grade Predictor System ---
# Enter student name, then hit Enter: Jay
# Enter 5 scores separated by spaces (e.g., 80 90 75 88 92): 100 90 85 75 80
#
# GRADE REPORT
# Student: Jay
# Average Score: 86.0
# Final Decision: University Ready
#
# Success! A permanent copy has been saved to Jay_report.txt

# %%
# Class and Object

#Define a class
class Student:    #class Stident definition
  def __init__(self,name,age):    #the method __init__ is executed automatically when object of class is created
    self.name=name          #attribute name is defined and assigned a value
    self.age=age            #attribute age is defined and assigned a value

  def greet(self):         #another method of class defined
    print(f'Hello, my name is {self.name}')

  def report_age(self):
    print(f'& I am {age} years old ')

#Object creation of class Student
student1=Student('Jojo',15) #object1 called student1
student2=Student('Roy',16)  #object2 called student2

#make object do something
student1.greet()
student1.report_age()
# Out:
# Hello, my name is Jojo
# & I am 15 years old
