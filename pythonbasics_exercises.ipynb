# %% [markdown]
# <a href="https://colab.research.google.com/github/atul799/AI-Essentials-Course/blob/main/pythonbasics_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Exercise sheet is to be used in the class
# to practice along of the concept of python discussed.
#
# The top comment of each code block mentions the topic the exercise covers
#
# #some part of code is already written for you
# #missing code is suppsed to be written by students (wherever you will find UPPERCASE COMMENTS, it will indicate a code from you is expected)
# #When the first line of the code block is :
#
# #no missing code - run this code block --> no code expected from student in that block
#
# #Student to write code.  --> student has to write in that block look at comment line with capital letters

# %%
#no missing code - run this code block
#Python is case sensitive

#variable definition
name1="Alex"
name2="alex"

#the check below shows that the Alex and alex is not the same for python
print("is name1 same as name2?",name1==name2)
# Out:
# is name1 same as name2? False

# %%
#Student to write code
#This is how you write comments in Python code

#I am single line comment
name1="Alex" #I am inline comment
"""I am a multi-
line
comment"""

#WRITE YOUR OWN SINGLE LINE COMMENT


#WRITE YOUR OWN MULTI LINE COMMENT
# Out:
# 'I am a multi-\nline\ncomment'

# %%
#no missing code - simply run the code
#Code blocks are identified by indentation in Python

#Indentation is space or tab, consistency is key
#The code below is a logic block
#notice the lines between if and else is indented
if 5>2:
  print("5 is greater than 2")
  print(" Still in if block")
else:     # notice else is a separate code block
  print("5 is not greater than 2")
  print(" Now in else block")

#print statement showing once if -else ends the indentation
#goes back to previous level
print("Now outside of if block")
# Out:
# 5 is greater than 2
#  Still in if block
# Now outside of if block

# %%
#Student to write code
#Variable naming rules

#variables cant start with numbers
#variable names cant use - in name
#variable name cant have spaces
#variable names cant use python key words (reserved words)

#Valid Variable names
myage=15 #starts with an alphabet, no dash
myName="guess" #starts with alphabet, no space or -
your_age=15 # _ are allowed but not -

#print the variables above
print(myage,myName,your_age)


#DISABLE THE COMMENTS BELOW ONE BY ONE TO SEE THAT VARIBLES
#BELOW ARE INVALID
#Invalid Variable names
#1age=15 #invalid
#uncomment below lines to find out variable naming error
#2age=15 #invalid, starts with number
#student-name="Joy" #invalid - in name
#temp=python  #invalid python is a reserved word
# Out:
# 15 guess 15

# %%
#no missing code - simply run the code
#Error messages and debug
#1. Syntax Error - code block
if x>5 print("X is greater than 5")

# %%
#no missing code - simply run the code
#Error messages and debug
#2. Indentation  Error
if x > 5:
  print("X is greater than 5")
 print("X is greater than 5")

# %%
#no missing code - simply run the code
#Error messages and debug
#2. Runtime Error - crash
a=10
b=0
result=a/b
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3820425879.py in <cell line: 0>()
#       4 a=10
#       5 b=0
# ----> 6 result=a/b
#       7 print(result)
#
# ZeroDivisionError: division by zero

# %%
#no missing code - simply run the code
#Error messages and debug
#3. Logic Error:
#the code is executed but results are wrong
#placing print statements to test intermediate
#variable values and logical tests are
#most common method to debug logical error
age = 16

if age > 20:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are an adult

# %%
#Student to write code
#Print statement
#are used to print variable or condition value

#Print fixed string
print("Hello, how do you do")

#WRITE A PRINT STATEMENT PRINTING Hello World!

#Print with fixed text and variable value
student_age=12
student_name="Alex"
print("Age and name of student is ",student_age,student_name)

#Formatted print with string variable intermixed
print(f"Name of student is {student_name} and his age is {student_age}")

#WRITE A PRINT STATEMENT PRINTING Student aged 12 is named Alex

#you can have a default separator between varibales in print
print("AI","ML","Python",sep="| ")

#Normally print statement adds a new line, if you dont want your prints
#to use a new line use the below print variant
print("Loading", end=" ")
print("Done")

#print patterns
print("*"*20) #print *20 times

#PRINT A LINE PRINTING ----------
# Out:
# Hello, how do you do
# Age and name of student is  12 Alex
# Name of student is Alex and his age is 12
# AI| ML| Python
# Loading Done
# ********************

# %%
#Student to write code
# Variables
#Integer value
x=12
z=x #value of z and x is same,when x changes z’s value is updated
y=z+1 # y is 13 (12+1)
print("value of y is: ",y)
student_age = 16

#DEFINE A VARIABLE NAMED weight AND ASSIGN VALUE 45


#String Variables store the student's name and age
character_name="c" #single character
student_name = "Alex"  #string variable
print("Char is: ",character_name, "student_name: ",student_name)

# float (real) variable
x=2.0
y= x+ 3 #result y=5.0
print("Value of y is:",y)

#DEFINE A VARIABLE NAMED color AND ASSIGN VALUE blue

#DEFINE A VARIBLE NAMED decoration containg 10 times *
# Out:
# value of y is:  13
# Char is:  c student_name:  Alex
# Value of y is: 5.0

# %%
#Student to write code
#Data Structure:
#1.List

#list definition
LLM_names=["GPT","Claude","Llama","Qwen"] #list with string
numbers=[10,20,30,40] #list containing number

#Access to elements of list
print("whole list:",numbers) #print all the list value
print("first element:",numbers[0]) #print first list element 10
print("third element:",numbers[2]) #print third list element 30
print("last element:",numbers[-1]) #reverse indexing also works -1 is last element
print("last but one element:",numbers[-2]) #-2 is second last element
print("second to fourth elements",numbers[1:4])  #slices of list can also be printed


#DEFINE A LIST NAMED days WITH VALUES Monday,Tuesday,3,Thursday,5

#PRINT FIRST, THIRD AND LAST ELEMENTS oF LIST days

#DEFINE AN EMPTY LIST empty_list


#changing list values
numbers[1]=25 #changing second elemnt from 20 to 25
print("numbers list is after index based change: ",numbers)  #[10,25,30,40]

#add an element at end of list
numbers.append(50) #add 50 at thne end of list
print("numbers list is after append: ",numbers) #[10,25,30,40,50]

#ADD TWO ELEMENTS red AND blue TO THE LIST empty_list

#add an element to list at specific index
numbers.insert(3,35) #add 35 at index 2
print("numbers list is after insert: ",numbers) ##[10,25,35,30,40,50]

#remove element from the list
numbers.remove(25) #remove an element from list by value
print("numbers list is after remove: ",numbers) #[10,35,30,40,50]

#remove element at specific index
numbers.pop(2) #remove an element at a position
print("numbers list is after pop: ",numbers) #[10,30,40,50]

#find out how many elements are in the list
length=len(numbers)
print("length of list is:",length)

#find if an element is in the list
in_list=["Claude" in LLM_names]
print("Claude is in the list?:",in_list)



#Set --> set is a special list thathas only unique values
numbers_set={10,20,20,30,30,40}
print("numbers_set:",numbers_set)

# %%
#Student to write code
#Data Structure:
#2.Dictionary

#Dictionary definition
student = { #dictionary storing record for a student
"name": "Joy",
"age": 13,
"subjects": ["Math", "Science"],
"grade" : 9
}

#Access to elements of dictionary - unsafe way
print("Student name: ",student["name"]) #print value of key name in dictionary
print("Student age: ",student["age"]) #print value of key age in dictionary
print("Student subjects: ",student["subjects"]) #print value of key subjects in dictionary
#print("Student hobby: ",student(["hobby"])) #print value of key hobby in dictionary

#DEFINE A DICTIONARY NAMED house WITH KEYS rooms,furniture  & VALUES 3,[Sofa,Bed,Dining table]

#PRINT VALUES FOR KEYS rooms and furniture

#DEFINE AN EMPTY DICTIONARY empty_dict


#access to elements of dictionary - safe way
print("student name: ",student.get("name"))  #safe access to key name
print("student hobby: ",student.get("hobby"))  #safe access to key hobby - doesnt exist

#add key value pair to dictionary
student["hobby"] = "Painting"
print("student hobby: ",student["hobby"])  #now hobby is defined so this wont be an error

#ADD KEY VALUE PAIR grade:9 TO DICTIONARY empty_dict

#modify value of existing key's value
student["age"] = 12
print("student modfied age: ",student["age"])  #changed age of student

#removing a key value from dictionary
del student["grade"] #remove grade key from dictionary
print("dictionary after removing key grade: ",student)

student.pop("subjects") #remove grade key from dictionary
print("dictionary after removing key subjects: ",student)

#checking if a key exists in a dictionary
print("does student dictionary has key name? :","name" in student)

#FIND IF KEY grade EXIST IN DICTIONARY empty_dict
# Out:
# Student name:  Joy
# Student age:  13
# Student subjects:  ['Math', 'Science']
# student name:  Joy
# student hobby:  None
# student hobby:  Painting
# student modfied age:  12
# dictionary after removing key grade:  {'name': 'Joy', 'age': 12, 'subjects': ['Math', 'Science'], 'hobby': 'Painting'}
# dictionary after removing key subjects:  {'name': 'Joy', 'age': 12, 'hobby': 'Painting'}
# does student dictionary has key name? : True

# %%
#Student to write code
#Logical operators and comparisons

a=12
b=14

#Comparison operator
#1. == equal to
print("is a equal to b: ", a==b) #equality check

#2. != not equal to
#WRITE PRINT STATEMENT FOR NONEQUALITY CHECK FOR a AND b


#3. > greater than
print("is a greater than b: ", a>b) #greater than check

#4. < less than check
#WRITE PRINT STATEMENT FOR LESS THAN CHECK FOR a AND b

#5. >= greater than or equal to
#WRITE PRINT STATEMENT FOR GREATER THAN EQUAL TO  CHECK FOR a AND b


#6. <= less than or equal to
print("is a less than or equal to b: ", a<=b) #less than or equal to check

#7. Chained comparison
print("is a between 10 and 14?: ", 10<a<14) #chained comparison

# Logic operation

w=1
x=True
y=0
z=False

#not - inversion
print("not w is: ",not w) #not of w --> 0/False
#WRITE PRINT STATEMENT INVERTING z
print("not z is: ",not z) # not of z -->True/1

#or - 1/True if one or more input is 1/True
print("x or y is: ",x or y) #x or y --> True
print("y or z is:", y or z) #y or z --> False
#WRITE PRINT STATEMENT SHOWING RESULT OR w & NOT x
print("w or x is:",w or x) #w or x --> True

#and  Tue only when all inputs are 1/True False otherwise
print("x and y is: ",x and y) #x and y --> False
print("y and z is:", y and z) #y and z --> False
print("w and x is:",w and x) #w and x --> True
# Out:
# is a equal to b:  False
# is a greater than b:  False
# is a greater than or equal to b:  False
# is a less than or equal to b:  True
# is a between 10 and 14?:  True
# not w is:  False
# not z is:  True
# x or y is:  True
# y or z is: False
# w or x is: 1
# x and y is:  0
# y and z is: 0
# w and x is: True

# %%
#Student to write code
#control flow

#if elif else
###########################
#Normally program execution happens line after another from top to end
print("Start") #the program start here
print("Middle") #then goes to next line and to next
print("End")   #until the end of code file
#############################

#if elif else is used to control the flow of program sequence
#for some logic you may want to execute specific set of code and not other
print() #print a blank line
#simple if
#program executuion starts here
controlflow=0 #variable used to decide controlflow
print("Start") #next line executed normally
if controlflow==1: #control flow check with of statement
  print("Middle") #this line is executed only if controlflow variable is set to 1

print("End") # End of program, will be printed as it is not part of if block


#if else : if condition true do somethings if not do another set of things

score=65 #variable to check condition for
if score >60:
  print("Passed the test")
else:
  print("Failed the test")

print() #print a blank line

#WRITE A CODE WITH VARIABLE DEFINITION t1 VALUE 0, u1 VALUE 9
#WHEREIN IF CONDITION > 10 IS TRUE THEN ADD 2 to t1 IF FALSE SUBTRACT
#5 FROM t1


print() #print a blank line
#if elif else : if true do something elif tru do smoething else if none true do default things
score=85 #variable to check condition
if score >=90: #run next print statement if score is >=90
  print("Grade A") #print and get out of if block
elif score >=70: #if first condition was not tru only then test if score >=70
  print("Grade B")
elif score >=50: #if first & second condition was not tru only then test if score >=50
  print("Grade C")
else:
  print("Grade D")
# Out:
# Start
# Middle
# End
#
# Start
# End
# Passed the test
#
#
# Grade B

# %%
#Student to write code
#control flow

#for loop
#for loop loops a block of code for a specified number of times
#range(3) --> creates a list [0,1,2]
#variable i is assigned a value from range(3) list on every loop round
for i in range(3) : #loop the next block, initialise variable i with first value in list
#and increment i on every iteration
  print(i) #print value of i in each iteration

print() #print blank line

#another example, looping through a list
subjects = ["Math", "Science", "English"] #list of subjects

for subject in subjects: #iterate 3 times (len(subjects)=3),
#assigning each list elem to variable subject
    print(subject)

print() #print blank line

#WRITE A FOR LOOP TO PRINT TOYS IN toy_box LIST BELOW
#toy_box = ["Rubber Ball", "Squeaky Bone", "Laser Pointer", "Catnip Mouse"]
# A list of items in our pet's toy box
toy_box = ["Rubber Ball", "Squeaky Bone", "Laser Pointer", "Catnip Mouse"]


#continue and break to skip one iteration or get out of loop immediately
looplist=[0,1,2,3] # same as range(4)
for i in looplist: #loop on looplist with var i assigned the values from list
  if i==2: #check when value of i is equal to 2
    print("gotta get out of loop",i)
    break #break the loop and get out of loop block
  print("reporting i from outside  pre-break",i)

#WRITE A FORLOOP TO CHECK IF Laser Pointer IS IN  THE toy_box


print() #print blank line
for i in looplist: #loop on looplist with var i assigned the values from list
  if i==2: #check when value of i is equal to 2
    print("will skip this iteration only: ",i)
    continue #break the loop and get out of loop block
  print("reporting i from outside continue ",i)


print() #print blank line

#looping through dictionaries
student = {
    "name": "Lina",
    "Math": 85,
    "Science": 78,
    "English": 92
} #dictionary definition

for subject, score in student.items(): #2 keys of dict assigned to subject and value to score on each iteration
    if subject != "name": #skip printing key value for name key
        print(subject, ":", score)

print() #print blank line
#Nested loop
for row in range(1, 4): #outer loop with list 1,2,3
    for col in range(1, 4): #inner loop with list 1,2,3
        print(row, col) #print row and col variable value for nested loop
 #total loop count = 3(inner)x3(outer) = 9)
# Out:
# 0
# 1
# 2
#
# Math
# Science
# English
#
# reporting i from outside  pre-break 0
# reporting i from outside  pre-break 1
# gotta get out of loop 2
#
# reporting i from outside continue  0
# reporting i from outside continue  1
# will skip this iteration only:  2
# reporting i from outside continue  3
#
# Math : 85
# Science : 78
# English : 92
#
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
#Student to write code
#control flow

#while loop
#while keeps looping until a condition becomes false
#be careful as you may accidently write infinite loop

#count up example
count=0 #variable to use as condition, initialise as 0
while count <3: #loop until count is below 3
  print("loop number: ",count) #print count
  count=count+1 #increase value of count by 1

print() #print blank line

#WRITE A WHILE LOOP WHICH LOOPS UNTIL A DOG CLIMBS TOP OF STAIRS
#USING FOLLOWING VARIABLES
stair_height=3 #totalheight of stair steps
stair_step=0.5  #height of single step of stair
stairs_scaled=0 #track how many steps already scaled

print() #print blank line
#count down example
count=3 #variable to use as condition, initialise as 3
while count >= 0 : #loop until count is below 3
  print("loop number: ",count) #print count
  count -=1 #decrease value of count by 1

print() #print blank line
# Out:
# loop number:  0
# loop number:  1
# loop number:  2
#
#
# loop number:  3
# loop number:  2
# loop number:  1
# loop number:  0

# %%
#Student to write code
# code optimization with function

#function is block of code that is evaluated separately
#mainly used to  group specific tasks done repeatedly in to a function definition

#simple function definition without parameter and return value
def greet(): #function with name greet is defined
  print("Howdy")
#function doesnt execute byitlsef, it has to be  "called" in main program section
#calling the function
print("How would you greet me??") #start of program
greet() #calling the function

print() #print blank line

#function definition with parameter
def greet(name): #function greet with 1 parameter name defined
#the parameter can be used as a variable in the function
  print("Howdy",name)

#calling the function
print("How would you greet Joy??") #start of program
greet("Joy") #calling the function with arguement Joy to be assigned to parameter name
print("How would you greet Alex??") #start of program
greet("Alex") #calling the function with arguement Alex to be assigned to parameter name

print() #print blank line

#function definition with parameter and return value
def add(a,b,c): #function add defined with three parameters
  calc_sum=a+b+c
  return calc_sum #return value
#call function
sum=add(3,5,6) #faunction called and return value saved in sum variable
print("sum of 3,5,6 is: ",sum)
print() #print blank line
#WRITE A FUNCTION check_study_result WHICH TAKES 2 INPUT PARAMETERS
#note, study_hours AND RETURNS 2 VALUES: success, message
#THE FUNCTION CHECKS IF note < 2.5 True success IS SETT TO True
#AND message IS SET TO Great job! You reached the target note.
#IF FALSE sucess IS SET TO False AND message More than study_hours hpurs of study is needed to reach the target..

# This function checks whether a student reached the goal
# Inputs:
#   note        → student's current note
#   study_hours → how many hours the student studied
# Outputs:
#   success     → True or False
#   message     → explanation text

#ADD MISSING CODE PIECES IN THE TEMPLATE BELOW
def check_study_result(): #MISSING CODE

    # Define the target note
    target_note = 2.5

    # Check if the note is good enough
    if note <= target_note:
        #MISSING CODE
        pass
    else:
        #MISSING CODE
        pass

    # Return two values
    #MISSING CODE

# Example values
current_note = 3
hours_of_study = 6

# Call the function
#MISSING CODE

# Print return values
#MISSING CODE
# Out:
# How would you greet me??
# Howdy
#
# How would you greet Joy??
# Howdy Joy
# How would you greet Alex??
# Howdy Alex
#
# sum of 3,5,6 is:  14

# %%
#Student to write code
#input and file I/O

#some programs may need user inputs
#in some cases you may need to write output of programs to a file
#or read data from existing files

#1. user input
#computer will wait for user input
student_name=input("type your name: ")
print("your name is: ",student_name)
print() #print blank line

#GET USER INPUT INTO A VARIABLE age
#IF age ENTERED IS GREATE THAN EQUAL TO 18, PRINT You are Adult
#IF LESS THAN 18 PRINT You are a Minor
#IF THE USER DOENST ENTER A VALUE OR NOT A NUMBER ASK AGAIN TO ENTER VALUE
#GIVE USER 3 CHANCES BEFORE QUITTING

#UNCOMMENT THE CODE BELOW ADD MISSING CODE PIECES IN THE TEMPLATE BELOW
'''
# Number of attempts allowed
max_attempts = 3

# Counter to track how many attempts were used
attempts = 0

# Keep asking while attempts are less than max_attempts
#MISSING CODE

    # Ask user for age from the terminal
    #MISSING CODE

    # Check if the input is a number
    if user_input.isdigit():

        # Convert the input string to an integer
        age = int(user_input)

        # Check age condition and print messages
        #MISSING CODE

        # Exit the loop after valid input
        break

    else:
        # Input was empty or not a number
        attempts = attempts + 1
        print("Invalid input. Please enter a number.")

        # Check if attempts are exhausted and print a message before quitting
        #MISSING CODE
'''
print() #print blank line
#2. File I/O
#2.1 file write
report_text1=(f"Report for {student_name}: Passed with flying colors")
report_text2=("Recommend to promote to next grade")
#create a file handle by open a file in write mode
fhandle=open("report.txt","w") #create a file report.txt in write mode
fhandle.write(report_text1+"\n") #write line 1 to file
fhandle.write(report_text2) #write line 2 to file
fhandle.close() #close the file
print() #print blank line

#2.2 file read , using with with open method that closes file automatically(safer)
# 2.2.1lets read the file we just created and read all contents of it at one go
with open("report.txt", "r") as f:
    file_contents = f.read()
    print("Read all file contents at one go")
    print((file_contents))
print() #print blank line
# 2.2.2 lets read file line by line
with open("report.txt", "r") as f:
    print("Reading file content line by line")
    i=0
    for line in f:
        print("Line: ",i,line.strip())
        i+=1

print() #print blank line
# Out:
# type you name: Great
# your name is:  Great
#
#
#
# Read all file contents at one go
# Report for Great: Passed with flying colors
# Recommend to promote to next grade
#
# Reading file content line by line
# Line:  0 Report for Great: Passed with flying colors
# Line:  1 Recommend to promote to next grade

# %%
#Student to write code
'''Study Planning Assistant

students notes are available for 5 subjects, he has 30 hours in a week
improve grade in each subject to euqual or below 2.5 and on avg 3
plot the improvement

'''

# Import matplotlib for creating plots
# This library helps us visualize data using charts
import matplotlib.pyplot as plt

#----------Step 1 -------------------------------------
#define data structures

# A list stores multiple items in a fixed order
# DEFINE A LIST  subjects CONTAINING Maths,German,Science,Ethics

# MISSING CODE

# Dictionary stores data as key-value pairs
# Key   → Subject name
# Value → Current note for that subject

#FILL THE DICTIONARY current_notes WITH CURRENT NOTES FOR EACH SUBJECT IN subjects
#CURRENT NOTE IN  Maths is  3.0, History 3.0, German 4.0, Science 3.0 & Ethics 3.0

current_notes = {
    #MISSING CODE
}

# This dictionary tells us how many study hours are needed
# to improve a subject by 0.5 note
hours_per_half_grade = {
    "Maths": 5,
    "History": 3,
    "German": 5,
    "Science": 3,
    "Ethics": 2
}


#-------------Step2------------------------------------
#define functions

#function needs_improvement checks whether a subject note
# is higher (worse) than our target note of 2.5
#DEFINE FUNCTION needs_improvement WHICH TAKE 1 PARAMETER note
#CHECKS IF note is greater than or equal to 2.5 THEN RETURNS True
# IF note IS LESS THAN 2.5 IT RETURNS FALSE

#MISSING CODE

# This function calculates how many study hours
# are needed to bring all subjects below note 2.5
def calculate_study_plan(notes, improvement_cost):

    # Dictionary to store how many hours to study per subject
    study_plan = {}

    # Variable to keep track of total required study hours
    total_hours = 0

    # Loop through each subject and its current note
    for subject, note in notes.items():

        # Check if this subject needs improvement
        if needs_improvement(note):

            # Calculate how many 0.5 steps are needed
            # Example: from 4.0 to 2.0 → (4.0 - 2.0) / 0.5 = 4 steps
            steps_needed = int((note - 2.0) / 0.5)

            # Calculate total hours for this subject
            hours_needed = steps_needed * improvement_cost[subject]

            # Store result in study plan
            study_plan[subject] = hours_needed

            # Add to total hours
            total_hours += hours_needed

        else:
            # If no improvement needed, assign 0 hours
            study_plan[subject] = 0

    # Return both the study plan and total hours required
    return study_plan, total_hours

#-------------Step 3----------------------------------------
#Define constraints

# Total number of hours the student can study per week
available_hours = 30

#-----------Step 4-------------------------------------------
#execution of program

# Call the function to calculate study hours
#CALL THE FUNCTION TO CALCULATE STUDY HOURS AND STORE RETURN VALUES IN
#study_plan total_required_hours
study_plan={}
total_required_hours=0
#MISSING CODE

# Print the study plan in a readable way
print(" Weekly Study Plan")
print("-------------------")

for subject, hours in study_plan.items():
    print(subject, "-->", hours, "hours")

print("\nTotal study hours needed:", total_required_hours)

#check time constraint
# Check if the study plan fits into available time
if total_required_hours <= available_hours:
    print("Study plan fits within available time.")
else:
    print("Not enough study hours available.")


#check average note
# Variable to store sum of all notes
total_notes = 0

# Loop through all subject notes
for note in current_notes.values():
    total_notes += note

#CALCULATE AVERAGE NOTE average_note
#USING total_notes and current_notes VARIABLES
average_note=0
#MISSING CODE

print("\nCurrent average note:", average_note)

# CHECK IF AVERAGE GOAL IS MET
#PRINT Average goal achieved. IF MET
#PRINT Average needs improvement.  IF NOT MET

#MISSING CODE


#----------------Step 5-----------------------------
#Visualization
# Prepare data for plotting
subject_names = list(current_notes.keys())
notes = list(current_notes.values())

# Create a bar chart
plt.bar(subject_names, notes)

# Draw a horizontal line showing target note (2.5)
plt.axhline(y=2.5, linestyle="--")

# Add labels and title
plt.xlabel("Subjects")
plt.ylabel("Current Note (Lower is Better)")
plt.title("Student Current Grades Overview")

# Show the plot
plt.show()
# Out:
#  Weekly Study Plan
# -------------------
#
# Total study hours needed: 0
# Study plan fits within available time.
#
# Current average note: 0
